# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriiYermak/DataScience/blob/main/HW2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive

# Монтуємо Google Drive
drive.mount('/content/drive')

# Шлях до файлу на Google Drive
path = '/content/drive/My Drive/Colab Notebooks/HW_2/2017_jun_final.csv'

# Читаємо CSV файл
df = pd.read_csv(path)

# Виводимо перші рядки DataFrame
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# ...

# %% [markdown]
# Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %% [markdown]
# Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Спеціалізація                       7219
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Університет                          358
# Ще студент                             0
# Рівень англійської                     0
# Предметна область                    223
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %% [markdown]
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
columns_to_drop = ["Спеціалізація", "Університет", "Предметна область", "Валюта", "cls"]
df_cleaned = df.drop(columns_to_drop, axis=1)
df_cleaned
# Out:
#          N                    Посада Мова програмування  \
# 0        1        Junior QA engineer                NaN
# 1        2        Junior QA engineer                NaN
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# ...    ...                       ...                ...
# 8699  8700               QA engineer                NaN
# 8700  8701                 Marketing                NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8702  8703                 Team lead                NaN
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %%
# Підрахунок кількості учасників для кожної мови програмування
counts = df['Мова програмування'].value_counts()

# Відсортувати дані в порядку зростання
counts = counts.sort_values()

# Побудова горизонтальної стовпчатої діаграми
plt.figure(figsize=(10, 8))
counts.plot(kind='barh', color='g')
plt.xlabel('Кількість учасників')
plt.ylabel('Мова програмування')
plt.title('Кількість учасників за мовою програмування')
plt.tight_layout()
plt.show()

# %% [markdown]
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
# Вибираємо рядки, де значення 'Мова програмування' не є пропущеним
filtered_df = df[df['Мова програмування'].notna()]

# Групуємо дані за 'Мова програмування' та обчислюємо середній заробіток
grouped_data = filtered_df.groupby('Мова програмування')['salary'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.bar(grouped_data['Мова програмування'], grouped_data['salary'], color='yellow')
plt.xlabel('Мова програмування')
plt.ylabel('Середня зарплата')
plt.title('Середня зарплата за мовою програмування')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df_cleaned.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Ще студент                             0
# Рівень англійської                     0
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %% [markdown]
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %% [markdown]
# Визначте новий розмір таблиці за допомогою методу shape

# %%
df_cleaned.shape
# Out:
# (8704, 20)

# %% [markdown]
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df_cleaned[df_cleaned["Мова програмування"] == "Python"]
python_data
# Out:
#          N                    Посада Мова програмування  \
# 12      13         Software Engineer             Python
# 68      69         Software Engineer             Python
# 87      88  Junior Software Engineer             Python
# 114    115  Junior Software Engineer             Python
# 143    144  Junior Software Engineer             Python
# ...    ...                       ...                ...
# 8546  8547         Software Engineer             Python
# 8625  8626         Software Engineer             Python
# 8635  8636  Senior Software Engineer             Python
# 8673  8674  Junior Software Engineer             Python
# 8695  8696         Software Engineer             Python
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# ...

# %% [markdown]
# Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped_data = python_data.groupby("Посада")
grouped_data

# %%
grouped_data_count = grouped_data.count()
print(grouped_data_count)
# Out:
#                             N  Мова програмування  Загальний досвід роботи  Досвід роботи на поточному місці  Зарплата на місяць  Зміна зарплати за 12 місяців  Місто  Розмір компанії  Тип компанії  Стать  Вік  Освіта  Ще студент  Рівень англійської  Дата заповнення  User.Agent  exp  current_job_exp  salary
# Посада
# Junior Software Engineer  63   63                  63                       63                                63                  63                            63     63               63            63     63   63      63          63                  63               63          63   63               63
# Senior Software Engineer  31   31                  31                       31                                31                  31                            31     31               31            31     31   31      31          31                  31               31          31   31               31
# ...

# %%
grouped_data_size = grouped_data.size()
print(grouped_data_size)
# Out:
# Посада
# Junior Software Engineer     63
# Senior Software Engineer     31
# Software Engineer           100
# System Architect              2
# Technical Lead               11
# dtype: int64

# %% [markdown]
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
aggregated_data = grouped_data.agg({"Зарплата на місяць": ["min", "max"]})
print(aggregated_data)
# Out:
#                          Зарплата на місяць
#                                         min   max
# Посада
# Junior Software Engineer                100  1250
# Senior Software Engineer               1300  9200
# Software Engineer                       500  5400
# System Architect                       3000  5000
# Technical Lead                         1425  6200

# %%
# Замініть 'position' на ваш стовпець з посадами і 'salary' на ваш стовпець з зарплатами
positions = df['Посада']
salaries = df['salary']

plt.figure(figsize=(10, 6))
plt.bar(positions, salaries, color='skyblue')
plt.xlabel('Посада')
plt.ylabel('Зарплата')
plt.title('Заробіток від посади')
plt.xticks(rotation=90)  # Повертаємо назви посад для кращої читабельності
plt.tight_layout()  # Автоматично підбирає розміри графіка
plt.show()

# %% [markdown]
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(group):
    group["avg"] = group["Зарплата на місяць"].mean()
    return group

df_avg = python_data.groupby("Посада").apply(fill_avg_salary)
df_avg
# Out:
#                                   N                    Посада Мова програмування Загальний досвід роботи Досвід роботи на поточному місці  Зарплата на місяць  Зміна зарплати за 12 місяців      Місто Розмір компанії   Тип компанії  ... Вік             Освіта Ще студент                    Рівень англійської      Дата заповнення                                                                                                                                User.Agent    exp  current_job_exp  salary          avg
# Посада                                                                                                                                                                                                                                 ...
# ...

# %%
df_avg.shape
# Out:
# (207, 21)

# %% [markdown]
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
df_avg["avg"].describe()
# Out:
# count     207.000000
# mean     1753.937198
# std       996.562606
# min       560.841270
# 25%       560.841270
# 50%      1799.070000
# 75%      1799.070000
# max      4000.000000
# Name: avg, dtype: float64

# %% [markdown]
# Збережіть отриману таблицю в CSV файл

# %%
df_avg.to_csv('/content/drive/My Drive/Colab Notebooks/HW_2/New_2017_final.csv', index=False)
